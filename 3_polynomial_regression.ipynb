# %% [markdown]
# ## import libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Prepare sample data

# %%
X = 6 * np.random.rand(100, 1) - 3
Y =0.5 * X**2 + 1.5*X + 2 + np.random.randn(100, 1)
# quadratic equation used- y=0.5x^2+1.5x+2+outliers
plt.scatter(X,Y,color='g')
plt.xlabel('X dataset')
plt.ylabel('Y dataset')
# Out:
# Text(0, 0.5, 'Y dataset')

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %% [markdown]
# ## 1. Solving Curve / non-linear data with Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
print('Coeffient or Slope:' ,regression.coef_)
print('Intercept:' ,regression.intercept_)
# Out:
# Coeffient or Slope: [[1.40085439]]
# Intercept: [3.60604348]

# %%
## Lets visualize this model
plt.plot(X_train,regression_1.predict(X_train),color='r')
plt.scatter(X_train,y_train)
plt.xlabel("X Dataset")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# ## 2. Solving Curve / Non-Linear Data with Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
## Ployinomial Regression has to be applied on the X train/test data set ( Just like we do for Standardisation)

poly=PolynomialFeatures(degree=2,include_bias=True)
X_train_poly=poly.fit_transform(X_train)
X_test_poly=poly.transform(X_test)

# %%
## bez the degree passed is 2, polyinomial regression prepared 2X's for the linear quaratic equation
## eg - 1 degree - y​=β0​+β1​x (same as linear regression) 
## 2 degree - y​=β0​+β1​x+β2​x2
## 3 degree - y=β0​+β1​x+β2​x2+β3​x3

X_train_poly
# Out:
# array([[ 1.00000000e+00,  6.73295985e-01,  4.53327484e-01],
#        [ 1.00000000e+00,  1.67765220e-03,  2.81451689e-06],
#        [ 1.00000000e+00, -2.86646247e+00,  8.21660707e+00],
#        [ 1.00000000e+00, -1.90188086e-01,  3.61715081e-02],
#        [ 1.00000000e+00, -1.89798248e+00,  3.60233750e+00],
#        [ 1.00000000e+00,  2.72778655e+00,  7.44081944e+00],
#        [ 1.00000000e+00,  1.33539291e+00,  1.78327424e+00],
#        [ 1.00000000e+00,  2.69931941e+00,  7.28632527e+00],
#        [ 1.00000000e+00,  6.93976042e-01,  4.81602747e-01],
#        [ 1.00000000e+00,  2.79993233e+00,  7.83962103e+00],
#        [ 1.00000000e+00, -2.10551258e+00,  4.43318321e+00],
#        [ 1.00000000e+00,  2.10697187e+00,  4.43933045e+00],
#        [ 1.00000000e+00,  3.59639306e-01,  1.29340430e-01],
#        [ 1.00000000e+00, -2.69968057e+00,  7.28827518e+00],
#        [ 1.00000000e+00,  3.25791606e-01,  1.06140170e-01],
#        [ 1.00000000e+00,  5.41129657e-01,  2.92821306e-01],
# ...

# %%
regression = LinearRegression()
regression.fit(X_train_poly, y_train)
y_pred = regression.predict(X_test_poly)

# %% [markdown]
# ## performance metrics

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.8813942118113398

# %% [markdown]
# ## plotting the polynomial fit line

# %%
plt.scatter(X_train,regression.predict(X_train_poly))
plt.scatter(X_train,y_train)
